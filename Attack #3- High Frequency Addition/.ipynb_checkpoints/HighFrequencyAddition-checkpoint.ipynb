# %%
import speech_recognition as sr
from os import path
import os.path
import operator
from os import system
from os import listdir
from os.path import isfile, join
import wave
import scipy as sc
import librosa
import IPython.display as ipd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
# %matplotlib inline
import math
import librosa as lb
import scipy
from sklearn.decomposition import PCA
import pandas as pd
from os import listdir
from os.path import isfile, join
import time
from itertools import product
import datetime
import sys
import librosa.display
import contextlib

# %%
#Read in the amplitude of the audio file
fs, data = scipy.io.wavfile.read(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\AudioFiles\helloAudio.wav")
length = len(data)
#print("This is the data printed\n", data[-100:])
print("This is the length of the sound wave:",length)
plt.plot(data)
# Out:
# This is the length of the sound wave: 216960

# %%
#Generates a high frequency sin wave
sampleRate = 48000
frequency = 8000
duration = 4.52 #how long the audio sound is in seconds

t = np.linspace(0, duration, sampleRate * duration)  #  Produces a 'duration' long Audio-File in seconds
y = np.sin(frequency * 2 * np.pi * t) * (0.1)

scipy.io.wavfile.write(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\Sine.wav", sampleRate, y)
plt.plot(y)
print("This is the length of the sin sound wave:",len(y))

#plt.plot(data)

#Use this to be able to make the sin wave broadcastable to the audio file you are testing
######np.ceil(length/sampleRate)
# Out:
# C:\Users\hamza\Anaconda3\envs\python3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# This is the length of the sin sound wave: 216959

# %%
scipy.io.wavfile.write(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\sampleWave.wav", sampleRate, data)

# %%
resultSound = np.add(data[:length-1] , y[:length] )
resultSound = np.asarray(resultSound,dtype=np.int16)
print(resultSound)
plt.plot(resultSound)
# Out:
# [   0    0    0 ...  -91 -182 -213]

# %%
type(data[0])
# Out:
# numpy.int16

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
axes[0].plot(data)
axes[1].plot(resultSound)

# %%
subAudio =np.subtract(resultSound, data[:length-1])
plt.plot(subAudio)

# %%
scipy.io.wavfile.write(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\sampleWave.wav", sampleRate, resultSound)

# %%
transcribe(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\sampleWave.wav", "google")
# Out:
# Google: -_-

# %%
def transcribe(my_path,model):
    wit_key = ''

    AUDIO_FILE =  path.join(my_path)

    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(my_path) as source:
        audio = r.record(source)  # read the entire audio file

    if(model == 'google'):
        # Google
        try:
            return r.recognize_google(audio)
        except sr.UnknownValueError:
             print("Google: -_-")
            
        except sr.RequestError as e:
            print("Google error; {0}".format(e))

# %%
#Get .wav file frames, sample rate, and duration
#fname = "C:\Users\hamza\OneDrive\Desktop\ResearchML\AudioFiles\helloAudio.wav"
with contextlib.closing(wave.open(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\AudioFiles\helloAudio.wav",'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    duration = frames / float(rate)
    print(frames)
    print(rate)
    print(duration)
# Out:
# 216960
# 48000
# 4.52

# %%
#Get .wav file frames, sample rate, and duration
with contextlib.closing(wave.open(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\Sine.wav",'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    duration = frames / float(rate)
    print(frames)
    print(rate)
    print(duration)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-221-c4c1f7d5c259> in <module>
#       1 #Get .wav file frames, sample rate, and duration
# ----> 2 with contextlib.closing(wave.open(r"C:\Users\hamza\OneDrive\Desktop\ResearchML\Sine.wav",'r')) as f:
#       3     frames = f.getnframes()
#       4     rate = f.getframerate()
#       5     duration = frames / float(rate)
#
# ~\Anaconda3\envs\python3\lib\wave.py in open(f, mode)
#     508             mode = 'rb'
#     509     if mode in ('r', 'rb'):
# --> 510         return Wave_read(f)
#     511     elif mode in ('w', 'wb'):
#     512         return Wave_write(f)
#
# ~\Anaconda3\envs\python3\lib\wave.py in __init__(self, f)
#     162         # else, assume it is an open file object already
#     163         try:
# --> 164             self.initfp(f)
#     165         except:
#     166             if self._i_opened_the_file:
#
# ~\Anaconda3\envs\python3\lib\wave.py in initfp(self, file)
#     142             chunkname = chunk.getname()
#     143             if chunkname == b'fmt ':
# --> 144                 self._read_fmt_chunk(chunk)
#     145                 self._fmt_chunk_read = 1
#     146             elif chunkname == b'data':
#
# ~\Anaconda3\envs\python3\lib\wave.py in _read_fmt_chunk(self, chunk)
#     267                 raise Error('bad sample width')
#     268         else:
# --> 269             raise Error('unknown format: %r' % (wFormatTag,))
#     270         if not self._nchannels:
#     271             raise Error('bad # of channels')
#
# Error: unknown format: 3
